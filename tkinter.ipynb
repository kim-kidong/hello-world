# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-kidong/hello-world/blob/master/tkinter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tkinter import *
def iCalc(source, side):
  storeObj = Frame(source, borderwidth = 1, bd = 4, bg = "yellow")
  storeObj.pack(side=side, expand=YES, fill=BOTH)
  return storeObj

def button(source, side, text, command = None) :
  storeObj = button(source, text=text, command=command)
  storeObj.pack(side=side, expand=YES, fill=BOTH)
  return storeObj   

class app(Frame):
  def __init__(self):
    Frame.__init__(self)
    self.option_add('*pont', 'arial 20 bold')
    self.pack(expand=YES, fill=BOTH)
    self.master.title('샵투 계산기')


    display = StringVar()
    Entry(self, relief=GROOVE, textvariable=display, justify='right', bd=30, bg='yellow').pack(side=side, expand=YES, fill=BOTH)



if __name__ == '__main__' :
  app()  . mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-81-544aa0787771> in <module>()
#      24
#      25 if __name__ == '__main__' :
# ---> 26   app()  . mainloop()
#
# <ipython-input-81-544aa0787771> in __init__(self)
#      12 class app(Frame):
#      13   def __init__(self):
# ---> 14     Frame.__init__(self)
#      15     self.option_add('*pont', 'arial 20 bold')
#      16     self.pack(expand=YES, fill=BOTH)
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, master, cnf, **kw)
#    2742             extra = ('-class', cnf['class'])
#    2743             del cnf['class']
# -> 2744         Widget.__init__(self, master, 'frame', cnf, {}, extra)
#    2745
#    2746 class Label(Widget):
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2290             cnf = _cnfmerge((cnf, kw))
#    2291         self.widgetName = widgetName
# -> 2292         BaseWidget._setup(self, master, cnf)
#    2293         if self._tclCommands is None:
#    2294             self._tclCommands = []
#
# /usr/lib/python3.6/tkinter/__init__.py in _setup(self, master, cnf)
#    2257             if not master:
#    2258                 if not _default_root:
# -> 2259                     _default_root = Tk()
#    2260                 master = _default_root
#    2261         self.master = master
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
